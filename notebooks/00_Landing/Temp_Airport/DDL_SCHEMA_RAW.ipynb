# %% [markdown]
# # Creacion de Schemas en raw

# %%
# %sql
CREATE CATALOG weather;

# %%
# %sql
CREATE SCHEMA weather.raw;

# %%
# %sql
CREATE VOLUME weather.raw.noaa_volume;

# %%
# %sql
CREATE VOLUME weather.raw.ana_volume;
